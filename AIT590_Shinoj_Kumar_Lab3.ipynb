# %%
import nltk
import spacy

# %%
from spacy import displacy
from collections import Counter
from pprint import pprint
nlp=spacy.load('en_core_web_sm')

# %%
from bs4 import BeautifulSoup
import requests
import re

# %% [markdown]
# ######  scrape the webpage in BeautifulSoup

# %%
#Using the web scraping technique with BeautifulSoup
def _scrape_webpage(url):
       
    request = requests.get(url)
    html = request.text
    soup = BeautifulSoup(html,'html5lib')
    
    for script in soup(["script","style","aside"]):
        script.extract()
    
    return " ".join(re.split(r'[\n\t]+', soup.get_text()))

# %%
news_web =_scrape_webpage('https://www.nytimes.com/2020/03/31/world/coronavirus-live-news-updates.html?action=click&module=Spotlight&pgtype=Homepage')
text = nlp(news_web)
print(news_web[:5000])
# Out:
#      Grim Models Project High U.S. Toll - The New York Times                                                                                           SectionsSEARCHSkip to contentSkip to site indexWorldLog InLog InToday’s PaperWorld|White House Projects Grim Toll From Coronavirushttps://nyti.ms/3aEdYAY                               The Coronavirus Outbreak                                                                                                             •                                   Latest Updates                                                                               Guide to Financial Help                                                                    Virus Tracker                                                                    Common Questions                                                                    What You Can Do                                                                    Newsletter                                         AdvertisementContinue reading the main storySupported byContinue reading the main storyWhite House Projects Grim Toll From CoronavirusThe scientists leading the administration’s fight estimated the virus could kill between 100,000 and 240,000 Americans. New data suggests many as 25 percent of infected people may not show symptoms.Published March 31, 2020Updated April 7, 2020This briefing has ended. Read our global live coverage on the coronavirus pandemic here.Here’s what you need to know:Models predicting expected spread of the virus in the U.S. paint a grim picture.President Trump strikes a somber note as he warns of a “painful two weeks ahead.”As many as 25 percent of people infected with the new coronavirus may not show symptoms.Ignoring party lines, governors challenge Trump’s assertions on availability of supplies.‘We are in a cage’: Spanish town lives under a lockdown within a lockdown.Americans are putting pride aside to seek aid.Saving its empty hotel rooms for hospital overflow, Las Vegas opens a homeless shelter in a parking lot.ImageMedical workers transferred the bodies of people who had died after contracting the virus to a temporary morgue in Brooklyn on Monday.Credit...Justin Lane/EPA, via ShutterstockModels predicting expected spread of the virus in the U.S. paint a grim picture.The top government scientists battling the coronavirus estimated Tuesday that the deadly pathogen could kill between 100,000 and 240,000 Americans, in spite of the social distancing measures that have closed schools, banned large gatherings, limited travel and forced people to stay in their homes.Dr. Anthony S. Fauci, the nation’s leading infectious disease expert, and Dr. Deborah L. Birx, who is coordinating the coronavirus response, displayed that grim projection at the White House on Tuesday, calling it “our real number” but pledging to do everything possible to reduce those numbers even further.The conclusions generally match those from similar models by public health researchers around the globe.As dire as those predictions are, Dr. Fauci and Dr. Birx said the number of deaths could be much higher if Americans do not follow the strict guidelines to keep the virus from spreading, and they urged people to take the restrictions seriously.President Trump, who on Sunday extended for 30 days the government’s recommendations for slowing the spread of the virus, made it clear that the data compiled by Dr. Fauci and Dr. Birx convinced him that the death toll would be even higher if the restrictions on work, school, travel and social life were not taken seriously by all Americans.The data released on Tuesday was the first time that Mr. Trump’s administration has officially estimated the breadth of the threat to human life from the coronavirus, and the disease it brings, known as Covid-19. In the past several weeks, Dr. Birx and Dr. Fauci have resisted predicting how many people might die in the pandemic, saying that there was not enough reliable data.That is no longer the  ...

# %% [markdown]
# ### Count all the named entities in the document

# %%
#Number of named entities
len(text.ents)
# Out:
# 667

# %%
text
# Out:
#      Grim Models Project High U.S. Toll - The New York Times                                                                                           SectionsSEARCHSkip to contentSkip to site indexWorldLog InLog InToday’s PaperWorld|White House Projects Grim Toll From Coronavirushttps://nyti.ms/3aEdYAY                               The Coronavirus Outbreak                                                                                                             •                                   Latest Updates                                                                               Guide to Financial Help                                                                    Virus Tracker                                                                    Common Questions                                                                    What You Can Do                                                                    Newsletter                                         AdvertisementContinue reading the main storySupported byContinue reading the main storyWhite House Projects Grim Toll From CoronavirusThe scientists leading the administration’s fight estimated the virus could kill between 100,000 and 240,000 Americans. New data suggests many as 25 percent of infected people may not show symptoms.Published March 31, 2020Updated April 7, 2020This briefing has ended. Read our global live coverage on the coronavirus pandemic here.Here’s what you need to know:Models predicting expected spread of the virus in the U.S. paint a grim picture.President Trump strikes a somber note as he warns of a “painful two weeks ahead.”As many as 25 percent of people infected with the new coronavirus may not show symptoms.Ignoring party lines, governors challenge Trump’s assertions on availability of supplies.‘We are in a cage’: Spanish town lives under a lockdown within a lockdown.Americans are putting pride aside to seek aid.Saving its empty hotel rooms for hospital overflow, Las Vegas opens a homeless shelter in a parking lot.ImageMedical workers transferred the bodies of people who had died after contracting the virus to a temporary morgue in Brooklyn on Monday.Credit...Justin Lane/EPA, via ShutterstockModels predicting expected spread of the virus in the U.S. paint a grim picture.The top government scientists battling the coronavirus estimated Tuesday that the deadly pathogen could kill between 100,000 and 240,000 Americans, in spite of the social distancing measures that have closed schools, banned large gatherings, limited travel and forced people to stay in their homes.Dr. Anthony S. Fauci, the nation’s leading infectious disease expert, and Dr. Deborah L. Birx, who is coordinating the coronavirus response, displayed that grim projection at the White House on Tuesday, calling it “our real number” but pledging to do everything possible to reduce those numbers even further.The conclusions generally match those from similar models by public health researchers around the globe.As dire as those predictions are, Dr. Fauci and Dr. Birx said the number of deaths could be much higher if Americans do not follow the strict guidelines to keep the virus from spreading, and they urged people to take the restrictions seriously.President Trump, who on Sunday extended for 30 days the government’s recommendations for slowing the spread of the virus, made it clear that the data compiled by Dr. Fauci and Dr. Birx convinced him that the death toll would be even higher if the restrictions on work, school, travel and social life were not taken seriously by all Americans.The data released on Tuesday was the first time that Mr. Trump’s administration has officially estimated the breadth of the threat to human life from the coronavirus, and the disease it brings, known as Covid-19. In the past several weeks, Dr. Birx and Dr. Fauci have resisted predicting how many people might die in the pandemic, saying that there was not enough reliable data.That is no longer the  ...

# %%
labels = [x.label_ for x in text.ents]
Counter(labels)
# Out:
# Counter({'ORG': 70,
#          'PERSON': 146,
#          'CARDINAL': 79,
#          'NORP': 55,
#          'PERCENT': 9,
#          'DATE': 95,
#          'GPE': 150,
#          'FAC': 2,
#          'ORDINAL': 11,
#          'TIME': 18,
#          'PRODUCT': 2,
#          'QUANTITY': 5,
#          'MONEY': 8,
#          'LOC': 11,
#          'LAW': 4,
#          'WORK_OF_ART': 2})

# %% [markdown]
# ### Count the most frequent tokens for the entire document

# %%
items = [x.text for x in text.ents]
Counter(items).most_common(15)
# Out:
# [('Trump', 28),
#  ('Tuesday', 20),
#  ('China', 15),
#  ('Americans', 14),
#  ('U.S.', 10),
#  ('American', 10),
#  ('the United States', 9),
#  ('Iran', 8),
#  ('first', 7),
#  ('one', 7),
#  ('Europe', 7),
#  ('New York', 6),
#  ('Las Vegas', 5),
#  ('two weeks', 5),
#  ('Putin', 5)]

# %% [markdown]
# ####  Pick a random integer K using Python random module, then pick three consecutive sentences starting with Kth, and print
# ####  these sentences. Note that you must make sure all picked sentences are in the document.

# %%
k = 30 
sentences = [x for x in text.sents]
print(sentences[k])
# Out:
# Anthony S. Fauci, the nation’s leading infectious disease expert, and Dr. Deborah L. Birx, who is coordinating the coronavirus response, displayed that grim projection at the White House on Tuesday, calling it “our real number” but pledging to do everything possible to reduce those numbers even further.

# %% [markdown]
# ### Extract part-of-speech and lemmatize these consecutive sentences

# %%
[(x.orth_, x.pos_, x.lemma_) for x in [y
                                    for y
                                    in nlp(str(sentences[k]))
                                     if not y.is_stop and y.pos_ != 'PUNCT']]
# Out:
# [('Anthony', 'PROPN', 'Anthony'),
#  ('S.', 'PROPN', 'S.'),
#  ('Fauci', 'PROPN', 'Fauci'),
#  ('nation', 'NOUN', 'nation'),
#  ('leading', 'VERB', 'lead'),
#  ('infectious', 'ADJ', 'infectious'),
#  ('disease', 'NOUN', 'disease'),
#  ('expert', 'NOUN', 'expert'),
#  ('Dr.', 'PROPN', 'Dr.'),
#  ('Deborah', 'PROPN', 'Deborah'),
#  ('L.', 'PROPN', 'L.'),
#  ('Birx', 'PROPN', 'Birx'),
#  ('coordinating', 'VERB', 'coordinate'),
#  ('coronavirus', 'PROPN', 'coronavirus'),
#  ('response', 'NOUN', 'response'),
#  ('displayed', 'VERB', 'display'),
#  ('grim', 'ADJ', 'grim'),
#  ('projection', 'NOUN', 'projection'),
#  ('White', 'PROPN', 'White'),
#  ('House', 'PROPN', 'House'),
#  ('Tuesday', 'PROPN', 'Tuesday'),
#  ('calling', 'VERB', 'call'),
#  ('real', 'ADJ', 'real'),
#  ('number', 'NOUN', 'number'),
#  ('pledging', 'VERB', 'pledge'),
#  ('possible', 'ADJ', 'possible'),
#  ('reduce', 'VERB', 'reduce'),
#  ('numbers', 'NOUN', 'number')]

# %% [markdown]
# ##### Get and print the named entity annotation for each token

# %%
dict([(str(x), x.label_) for x in nlp(str(sentences[k])).ents])
# Out:
# {'Anthony S. Fauci': 'PERSON',
#  'Deborah L. Birx': 'PERSON',
#  'the White House': 'FAC',
#  'Tuesday': 'DATE'}

# %%
pprint([(x, x.ent_iob_, x.ent_type_) for x in sentences[k]])
# Out:
# [(Anthony, 'B', 'PERSON'),
#  (S., 'I', 'PERSON'),
#  (Fauci, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (the, 'O', ''),
#  (nation, 'O', ''),
#  (’s, 'O', ''),
#  (leading, 'O', ''),
#  (infectious, 'O', ''),
#  (disease, 'O', ''),
#  (expert, 'O', ''),
#  (,, 'O', ''),
#  (and, 'O', ''),
#  (Dr., 'O', ''),
#  (Deborah, 'B', 'PERSON'),
#  (L., 'I', 'PERSON'),
#  (Birx, 'I', 'PERSON'),
#  (,, 'O', ''),
#  (who, 'O', ''),
#  (is, 'O', ''),
#  (coordinating, 'O', ''),
#  (the, 'O', ''),
#  (coronavirus, 'O', ''),
#  (response, 'O', ''),
#  (,, 'O', ''),
#  (displayed, 'O', ''),
#  (that, 'O', ''),
#  (grim, 'O', ''),
#  (projection, 'O', ''),
#  (at, 'O', ''),
#  (the, 'B', 'FAC'),
#  (White, 'I', 'FAC'),
#  (House, 'I', 'FAC'),
#  (on, 'O', ''),
#  (Tuesday, 'B', 'DATE'),
#  (,, 'O', ''),
#  (calling, 'O', ''),
#  (it, 'O', ''),
#  (“, 'O', ''),
#  (our, 'O', ''),
#  (real, 'O', ''),
#  (number, 'O', ''),
#  (”, 'O', ''),
#  (but, 'O', ''),
#  (pledging, 'O', ''),
#  (to, 'O', ''),
#  (do, 'O', ''),
#  (everything, 'O', ''),
#  (possible, 'O', ''),
#  (to, 'O', ''),
#  (reduce, 'O', ''),
#  (those, 'O', ''),
#  (numbers, 'O', ''),
#  (even, 'O', ''),
#  (further, 'O', ''),
#  (., 'O', '')]

# %% [markdown]
# #### Visualizing the entities of kth sentence

# %%
displacy.render(nlp(str(sentences[k])), jupyter=True, style = 'ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Anthony S. Fauci
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the nation’s leading infectious disease expert, and Dr.
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Deborah L. Birx
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , who is coordinating the coronavirus response, displayed that grim projection at
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the White House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">FAC</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tuesday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , calling it “our real number” but pledging to do everything possible to reduce those numbers even further.</div>

# %% [markdown]
# ###### Visualizing all the entities

# %%
displacy.render(nlp(str(sentences)), jupyter=True, style = 'ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">[
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Grim Models Project
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , High U.S. Toll -,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The New York Times
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                            SectionsSEARCHSkip, to contentSkip to site indexWorldLog
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     InLog InToday’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  PaperWorld|White
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Projects Grim Toll From Coronavirushttps://nyti.ms/3aEdYAY                               ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Coronavirus Outbreak
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , •                                   ,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Latest Updates
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#                                                                                Guide to Financial Help                                                                    ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Virus Tracker
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#                                                                     ,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Common Questions
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , What You Can Do                                                                    ,
# <mark class="entity" style="background: #f0d0ff; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Newsletter                                         AdvertisementContinue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">WORK_OF_ART</span>
# </mark>
#  reading the main storySupported
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     byContinue
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  reading the main storyWhite
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Projects Grim Toll From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CoronavirusThe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  scientists leading the administration’s, fight estimated the virus could kill
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 100,000 and 240,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# ., New data suggests many as
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of infected people may not show symptoms., Published March 31, 2020Updated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 2020This briefing has ended., Read our global live coverage on the coronavirus pandemic here., Here’s what you need to know:Models predicting expected spread of the virus in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  paint a grim picture., President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  strikes a somber note as he warns of a “painful
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two weeks ahead
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ., ”As
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">

# %% [markdown]
# #### Code for NER in spacy

# %%
text =nlp("President Trump strikes a somber note as he warns of a “painful two weeks ahead.”As many as 25 percent of people infected with the new coronavirus may not show symptoms.Ignoring party lines, governors challenge Trump’s assertions on availability of supplies.‘We are in a cage’: Spanish town lives under a lockdown within a lockdown.Americans are putting pride aside to seek aid.Saving its empty hotel rooms for hospital overflow, Las Vegas opens a homeless shelter in a parking lot.ImageMedical workers transferred the bodies of people who had died after contracting the virus to a temporary morgue in Brooklyn on Monday.Credit...Justin Lane/EPA, via ShutterstockModels predicting expected spread of the virus in the U.S. paint a grim picture.")
print(text)
# Out:
# President Trump strikes a somber note as he warns of a “painful two weeks ahead.”As many as 25 percent of people infected with the new coronavirus may not show symptoms.Ignoring party lines, governors challenge Trump’s assertions on availability of supplies.‘We are in a cage’: Spanish town lives under a lockdown within a lockdown.Americans are putting pride aside to seek aid.Saving its empty hotel rooms for hospital overflow, Las Vegas opens a homeless shelter in a parking lot.ImageMedical workers transferred the bodies of people who had died after contracting the virus to a temporary morgue in Brooklyn on Monday.Credit...Justin Lane/EPA, via ShutterstockModels predicting expected spread of the virus in the U.S. paint a grim picture.

# %%
#Annotate the token entity
pprint([(x, x.ent_iob_, x.ent_type) for x in text])
# Out:
# [(President, 'O', 0),
#  (Trump, 'B', 380),
#  (strikes, 'O', 0),
#  (a, 'O', 0),
#  (somber, 'O', 0),
#  (note, 'O', 0),
#  (as, 'O', 0),
#  (he, 'O', 0),
#  (warns, 'O', 0),
#  (of, 'O', 0),
#  (a, 'O', 0),
#  (“, 'O', 0),
#  (painful, 'O', 0),
#  (two, 'B', 391),
#  (weeks, 'I', 391),
#  (ahead, 'I', 391),
#  (., 'O', 0),
#  (”As, 'O', 0),
#  (many, 'O', 0),
#  (as, 'O', 0),
#  (25, 'B', 393),
#  (percent, 'I', 393),
#  (of, 'O', 0),
#  (people, 'O', 0),
#  (infected, 'O', 0),
#  (with, 'O', 0),
#  (the, 'O', 0),
#  (new, 'O', 0),
#  (coronavirus, 'O', 0),
#  (may, 'O', 0),
#  (not, 'O', 0),
#  (show, 'O', 0),
#  (symptoms, 'O', 0),
#  (., 'O', 0),
#  (Ignoring, 'O', 0),
#  (party, 'O', 0),
#  (lines, 'O', 0),
#  (,, 'O', 0),
#  (governors, 'O', 0),
#  (challenge, 'O', 0),
#  (Trump, 'B', 380),
#  (’s, 'O', 0),
#  (assertions, 'O', 0),
#  (on, 'O', 0),
#  (availability, 'O', 0),
#  (of, 'O', 0),
#  (supplies, 'O', 0),
#  (., 'O', 0),
#  (‘We, 'B', 383),
#  (are, 'O', 0),
#  (in, 'O', 0),
#  (a, 'O', 0),
#  (cage, 'O', 0),
#  (’, 'O', 0),
#  (:, 'O', 0),
#  (Spanish, 'B', 381),
#  (town, 'O', 0),
#  (lives, 'O', 0),
#  (under, 'O', 0),
#  (a, 'O', 0),
#  (lockdown, 'O', 0),
#  (within, 'O', 0),
#  (a, 'O', 0),
#  (lockdown, 'O', 0),
#  (., 'O', 0),
#  (Americans, 'B', 381),
#  (are, 'O', 0),
#  (putting, 'O', 0),
#  (pride, 'O', 0),
#  (aside, 'O', 0),
#  (to, 'O', 0),
#  (seek, 'O', 0),
#  (aid, 'O', 0),
#  (., 'O', 0),
#  (Saving, 'O', 0),
#  (its, 'O', 0),
#  (empty, 'O', 0),
#  (hotel, 'O', 0),
#  (rooms, 'O', 0),
#  (for, 'O', 0),
#  (hospital, 'O', 0),
#  (overflow, 'O', 0),
#  (,, 'O', 0),
#  (Las, 'B', 384),
#  (Vegas, 'I', 384),
#  (opens, 'O', 0),
#  (a, 'O', 0),
#  (homeless, 'O', 0),
#  (shelter, 'O', 0),
#  (in, 'O', 0),
#  (a, 'O', 0),
#  (parking, 'O', 0),
#  (lot, 'O', 0),
#  (., 'O', 0),
#  (ImageMedical, 'B', 383),
#  (workers, 'O', 0),
#  (transferred, 'O', 0),
#  (the, 'O', 0),
#  (bodies, 'O', 0),
#  (of, 'O', 0),
#  (people, 'O', 0),
#  (who, 'O', 0),
#  (had, 'O', 0),
#  (died, 'O', 0),
#  (after, 'O', 0),
#  (contracting, 'O', 0),
#  (the, 'O', 0),
#  (virus, 'O', 0),
#  (to, 'O', 0),
#  (a, 'O', 0),
#  (temporary, 'O', 0),
#  (morgue, 'O', 0),
#  (in, 'O', 0),
#  (Brooklyn, 'B', 384),
#  (on, 'O', 0),
#  (Monday, 'B', 391),
#  (., 'O', 0),
#  (Credit, 'O', 0),
#  (..., 'O', 0),
#  (Justin, 'B', 383),
#  (Lane, 'I', 383),
#  (/, 'I', 383),
#  (EPA, 'I', 383),
#  (,, 'O', 0),
#  (via, 'O', 0),
#  (ShutterstockModels, 'B', 383),
#  (predicting, 'O', 0),
#  (expected, 'O', 0),
#  (spread, 'O', 0),
#  (of, 'O', 0),
#  (the, 'O', 0),
#  (virus, 'O', 0),
#  (in, 'O', 0),
#  (the, 'O', 0),
#  (U.S., 'B', 384),
#  (paint, 'O', 0),
#  (a, 'O', 0),
#  (grim, 'O', 0),
#  (picture, 'O', 0),
#  (., 'O', 0)]

# %%
# Get the named entity
pprint([(x.text, x.label_) for x in text.ents])
# Out:
# [('Trump', 'PERSON'),
#  ('two weeks ahead', 'DATE'),
#  ('25 percent', 'PERCENT'),
#  ('Trump', 'PERSON'),
#  ('‘We', 'ORG'),
#  ('Spanish', 'NORP'),
#  ('Americans', 'NORP'),
#  ('Las Vegas', 'GPE'),
#  ('ImageMedical', 'ORG'),
#  ('Brooklyn', 'GPE'),
#  ('Monday', 'DATE'),
#  ('Justin Lane/EPA', 'ORG'),
#  ('ShutterstockModels', 'ORG'),
#  ('U.S.', 'GPE')]

# %%
#Detailed information for named entity
for ent in text.ents:
    print(ent.text, ent.start_char, ent.end_char,
         ent.label_, spacy.explain(ent.label_))
# Out:
# Trump 10 15 PERSON People, including fictional
# two weeks ahead 64 79 DATE Absolute or relative dates or periods
# 25 percent 92 102 PERCENT Percentage, including "%"
# Trump 211 216 PERSON People, including fictional
# ‘We 258 261 ORG Companies, agencies, institutions, etc.
# Spanish 278 285 NORP Nationalities or religious or political groups
# Americans 332 341 NORP Nationalities or religious or political groups
# Las Vegas 430 439 GPE Countries, cities, states
# ImageMedical 482 494 ORG Companies, agencies, institutions, etc.
# Brooklyn 602 610 GPE Countries, cities, states
# Monday 614 620 DATE Absolute or relative dates or periods
# Justin Lane/EPA 630 645 ORG Companies, agencies, institutions, etc.
# ShutterstockModels 651 669 ORG Companies, agencies, institutions, etc.
# U.S. 717 721 GPE Countries, cities, states

# %%
# visualization for named entity
displacy.render(text, jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">President
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  strikes a somber note as he warns of a “painful
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two weeks ahead
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .”As many as
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of people infected with the new coronavirus may not show symptoms.Ignoring party lines, governors challenge
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Trump
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# ’s assertions on availability of supplies.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ‘We
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are in a cage’:
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  town lives under a lockdown within a lockdown.
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  are putting pride aside to seek aid.Saving its empty hotel rooms for hospital overflow,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las Vegas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  opens a homeless shelter in a parking lot.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ImageMedical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  workers transferred the bodies of people who had died after contracting the virus to a temporary morgue in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brooklyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Monday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .Credit...
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Justin Lane/EPA
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , via
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ShutterstockModels
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  predicting expected spread of the virus in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  paint a grim picture.</div>

# %%
displacy.render(text, style='dep', jupyter=True, options ={'distance':75})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="26c08f8921264e5885d6ea7e9bc8f788-0" class="displacy" width="9350" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="125">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="125">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">strikes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">somber</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="425">note</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">warns</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="725">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">a “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="875">painful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="875">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1025">weeks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">ahead.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1175">”As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1175">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1325">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1325">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">25</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1475">percent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1475">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">infected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1775">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1925">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">coronavirus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2075">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2225">show</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">symptoms.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="disp

# %%
options={'distance':75, 'compact':'True', 'color':'yellow', 'bg':'#09a3d5', 'font':'Times'}
displacy.render(text, style='dep', options=options, jupyter='True')
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ae12a2c7ccdc4358a3c38d8dae976a22-0" class="displacy" width="9350" height="512.0" direction="ltr" style="max-width: none; height: 512.0px; color: yellow; background: #09a3d5; font-family: Times; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">President</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="125">Trump</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="125">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">strikes</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="275">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">somber</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="425">note</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="425">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="575">he</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">warns</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="725">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="725">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">a “</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="875">painful</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="875">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">two</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1025">weeks</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1025">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">ahead.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1175">”As</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1175">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">many</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1325">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1325">SCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">25</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1475">percent</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1475">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1625">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">infected</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1775">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1775">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="1925">new</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1925">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">coronavirus</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2075">may</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2075">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">not</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2225">show</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2225">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="422.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">symptoms.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displ

# %% [markdown]
# ###  De identification

# %%
def _replace_person_name(token):
    if token.ent_iob != 0 and token.ent_type_ == 'PERSON':
        return '[REDACTED]'
    return token.string

# %%
def _redact_names(nlp_doc):
    for ent in nlp_doc.ents:
        ent.merge()
        tokens = map(_replace_person_name, nlp_doc)
        return ''.join(tokens)

# %%
redacted = _redact_names(text)
print(redacted)
# Out:
#      Grim Models Project High U.S. Toll - The New York Times                                                                                           SectionsSEARCHSkip to contentSkip to site indexWorldLog InLog InToday’s PaperWorld|White House Projects Grim Toll From Coronavirushttps://nyti.ms/3aEdYAY                               The Coronavirus Outbreak                                                                                                             •                                   Latest Updates                                                                               Guide to Financial Help                                                                    Virus Tracker                                                                    Common Questions                                                                    What You Can Do                                                                    Newsletter                                         AdvertisementContinue reading the main storySupported [REDACTED]reading the main storyWhite House Projects Grim Toll From CoronavirusThe scientists leading the administration’s fight estimated the virus could kill between 100,000 and 240,000 Americans. New data suggests many as 25 percent of infected people may not show symptoms.Published March 31, 2020Updated April 7, 2020This briefing has ended. Read our global live coverage on the coronavirus pandemic here.Here’s what you need to know:Models predicting expected spread of the virus in the U.S. paint a grim picture.President [REDACTED]strikes a somber note as he warns of a “painful two weeks ahead.”As many as 25 percent of people infected with the new coronavirus may not show symptoms.Ignoring party lines, governors challenge [REDACTED]’s assertions on availability of supplies.‘We are in a cage’: Spanish town lives under a lockdown within a lockdown.Americans are putting pride aside to seek aid.Saving its empty hotel rooms for hospital overflow, Las Vegas opens a homeless shelter in a parking lot.ImageMedical workers transferred the bodies of people who had died after contracting the virus to a temporary morgue in Brooklyn on Monday.Credit...Justin Lane/EPA, via ShutterstockModels predicting expected spread of the virus in the U.S. paint a grim picture.The top government scientists battling the coronavirus estimated Tuesday that the deadly pathogen could kill between 100,000 and 240,000 Americans, in spite of the social distancing measures that have closed schools, banned large gatherings, limited travel and forced people to stay in their homes.Dr. [REDACTED][REDACTED][REDACTED], the nation’s leading infectious disease expert, and Dr. [REDACTED][REDACTED][REDACTED], who is coordinating the coronavirus response, displayed that grim projection at the White House on Tuesday, calling it “our real number” but pledging to do everything possible to reduce those numbers even further.The conclusions generally match those from similar models by public health researchers around the globe.As dire as those predictions are, Dr. [REDACTED]and Dr. [REDACTED]said the number of deaths could be much higher if Americans do not follow the strict guidelines to keep the virus from spreading, and they urged people to take the restrictions seriously.President [REDACTED], who on Sunday extended for 30 days the government’s recommendations for slowing the spread of the virus, made it clear that the data compiled by Dr. [REDACTED]and Dr. [REDACTED]convinced him that the death toll would be even higher if the restrictions on work, school, travel and social life were not taken seriously by all Americans.The data released on Tuesday was the first time that Mr. [REDACTED]’s administration has officially estimated the breadth of the threat to human life from the coronavirus, and the disease it brings, known as Covid-19. In the past several weeks, Dr. [REDACTED]and Dr. [REDACTED]have resisted predicting how many people might die in the pande ...

# %%
displacy.render(nlp(redacted), jupyter=True, style='ent')
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">     Grim Models Project High U.S. Toll - The New York Times                                                                                           SectionsSEARCHSkip to contentSkip to site indexWorldLog
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     InLog InToday’s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  PaperWorld|White
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Projects Grim Toll From Coronavirushttps://nyti.ms/3aEdYAY                               The Coronavirus Outbreak                                                                                                             •                                   Latest Updates                                                                               Guide to Financial Help                                                                    Virus Tracker                                                                    Common Questions                                                                    What You Can Do                                                                    Newsletter                                         AdvertisementContinue reading the main storySupported [REDACTED]reading the main storyWhite
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     House
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  Projects Grim Toll From
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     CoronavirusThe
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  scientists leading the administration’s fight estimated the virus could kill
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     between 100,000 and 240,000
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
# . New data suggests many as
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of infected people may not show symptoms.Published
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     March 31
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 2020Updated
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     April 7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , 2020This briefing has ended. Read our global live coverage on the coronavirus pandemic here.Here’s what you need to know:Models predicting expected spread of the virus in the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     U.S.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  paint a grim picture.President [REDACTED]strikes a somber note as he warns of a “painful
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     two weeks ahead
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .”As many as
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25 percent
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  of people infected with the new coronavirus may not show symptoms.Ignoring party lines, governors challenge [REDACTED]’s assertions on availability of supplies.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ‘We
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  are in a cage’:
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Spanish
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  town lives under a lockdown within a lockdown.
# <mark class="entity" style="background: #c887fb; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Americans
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NORP</span>
# </mark>
#  are putting pride aside to seek aid.Saving its empty hotel rooms for hospital overflow,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Las Vegas
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  opens a homeless shelter in a parking lot.
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ImageMedical
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  workers transferred the bodies of people who had died after contracting the virus to a temporary morgue in
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Brooklyn
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; m
